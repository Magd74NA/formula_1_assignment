# %%
import numpy as np  # For computations
import pandas as pd  # For indexing our data

#CSVS = ['circuits.csv','constructor_results.csv','constructor_standings.csv','constructors.csv','driver_standings.csv','drivers.csv','lap_times.csv','pit_stops.csv','qualifying.csv','races.csv','results.csv','seasons.csv',
#        'sprint_results.csv','status.csv']

#data = []

#for csv in CSVS :
#  data.append(pd.read_csv(csv))

#for dataset in data :
 # print(dataset.info())

#data_join = pd.read_csv('circuits.csv')

races = pd.read_csv('results.csv')

print(races.statusId.eq(104))


#print(races)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 27299    False
# 27300    False
# 27301    False
# 27302    False
# 27303    False
# Name: statusId, Length: 27304, dtype: bool
